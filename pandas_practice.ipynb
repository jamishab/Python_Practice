# %%
import pandas as pd

coffee_data = {
    "Drink": ["Latte", "Cappuccino", "Espresso", "Americano", "Mocha"],
    "Price": [4.50, 4.25, 3.00, 3.50, 5.00],
    "Caffeine_mg": [150, 150, 63, 120, 175],
    "In_Stock": [True, True, True, False, True]
}

coffee_df = pd.DataFrame(coffee_data)

print(coffee_df)

print(coffee_df.head(2))  # Display the first 2 rows of the DataFrame
print(coffee_df.describe())  # Display summary statistics for numerical columns

# Specify row labels
coffee_df.index = ['a', 'b', 'c', 'd', 'e']
print(coffee_df)
# Out:
#         Drink  Price  Caffeine_mg  In_Stock
# 0       Latte   4.50          150      True
# 1  Cappuccino   4.25          150      True
# 2    Espresso   3.00           63      True
# 3   Americano   3.50          120     False
# 4       Mocha   5.00          175      True
#         Drink  Price  Caffeine_mg  In_Stock
# 0       Latte   4.50          150      True
# 1  Cappuccino   4.25          150      True
#           Price  Caffeine_mg
# count  5.000000     5.000000
# mean   4.050000   131.600000
# std    0.798436    43.015114
# min    3.000000    63.000000
# 25%    3.500000   120.000000
# 50%    4.250000   150.000000
# 75%    4.500000   150.000000
# max    5.000000   175.000000
#         Drink  Price  Caffeine_mg  In_Stock
# a       Latte   4.50          150      True
# b  Cappuccino   4.25          150      True
# c    Espresso   3.00           63      True
# d   Americano   3.50          120     False
# e       Mocha   5.00          175      True
